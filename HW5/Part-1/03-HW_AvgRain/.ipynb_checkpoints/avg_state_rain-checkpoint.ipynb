# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
file = "Resources/avg_rain_state.csv"
df = pd.read_csv(file, low_memory = False)
df
# Out:
#              State  Inches  Milli­metres  Rank
# 0          Alabama    58.3          1480     4
# 1           Alaska    22.5           572    39
# 2          Arizona    13.6           345    47
# 3         Arkansas    50.6          1284     8
# 4       California    22.2           563    40
# 5         Colorado    15.9           405    44
# 6      Connecticut    50.3          1279     9
# 7         Delaware    45.7          1160    16
# 8          Florida    54.5          1385     5
# 9          Georgia    50.7          1287     7
# 10          Hawaii    63.7          1618     1
# 11           Idaho    18.9           481    42
# 12        Illinois    39.2           996    27
# 13         Indiana    41.7          1060    26
# 14            Iowa    34.0           864    31
# 15          Kansas    28.9           733    35
# 16        Kentucky    48.9          1242    12
# 17       Louisiana    60.1          1528     2
# 18           Maine    42.2          1072    23
# ...

# %%
# Set x axis and tick locations
x_axis = np.arange(len(df))
x_axis
tick_locations = x_axis

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize = (20,15))
plt.bar(x_axis, df["Inches"], color = 'red')
plt.xticks(tick_locations, df["State"], rotation = "vertical")
plt.yticks([0,25,50], [0,25,50])
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.YTick at 0x1c341cdeb00>,
# ...
#  <a list of 3 Text yticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-.50, len(x_axis))
plt.ylim(0, max(df["Inches"])+10)
#plt.tight_layout()
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Avg Rainfall per State")
plt.xlabel("State")
plt.ylabel("Inches Rainfall")
# Out:
# Text(0, 0.5, 'Inches Rainfall')

# %%
# Save our graph and show the graph
plt.savefig("Images/rainfall.png")
plt.show()
