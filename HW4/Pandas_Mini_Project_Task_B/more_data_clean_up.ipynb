# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
df = pd.read_csv(file, low_memory = False)
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
reduced_df = df.iloc[:,[0,1,2,3,4,6,  7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
reduced_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# 1             NaN  between 100,000 and 1 million  ...
# 2             NaN            more than 1 million  ...
# 3             NaN            more than 1 million  ...
# 4             NaN  between 100,000 and 1 million  ...
#
#                 CountryLive                        EmploymentField  \
# 0  United States of America      office and administrative support
# 1  United States of America                      food and beverage
# 2  United States of America                                finance
# 3  United States of America  arts, entertainment, sports, or media
# 4  United States of America                              education
#
#      EmploymentStatus  Gender HasChildren  HoursLearning   Income  \
# 0  Employed for wages    male         0.0           30.0  32000.0
# 1  Employed for wages    male         NaN           30.0  15000.0
# 2  Employed for wages    male         NaN           20.0  48000.0
# 3  Employed for wages  female         NaN           20.0  43000.0
# 4  Employed for wages  female         NaN           25.0   6000.0
#
#              JobRoleInterest                             SchoolDegree  \
# 0                        NaN           some college credit, no degree
# 1    Front-End Web Developer           some college credit, no degree
# 2                        NaN  high school diploma or equivalent (GED)
# 3    Front-End Web Developer                        bachelor's degree
# 4   Full-Stack Web Developer           some college credit, no degree
#
#                SchoolMajor
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3  Cinematography And Film
# 4                      NaN
#
# [5 rows x 21 columns]

# %%
# Change reading 0 and 1 to No and Yes, respectively
reduced_df = reduced_df.replace({0: 'No', 1: 'Yes'})
# Verify clean-up.
reduced_df['AttendedBootcamp'].value_counts()
# Out:
# No     14427
# Yes      953
# Name: AttendedBootcamp, dtype: int64

# %%
# Extract rows for only those who attended a bootcamp
attended_bc = reduced_df.loc[reduced_df["AttendedBootcamp"] == "Yes"]
attended_bc.count()
# Out:
# Age                     818
# AttendedBootcamp        953
# BootcampFinish          933
# BootcampFullJobAfter    635
# BootcampLoanYesNo       934
# BootcampName            895
# BootcampPostSalary      330
# BootcampRecommend       937
# ChildrenNumber          148
# CityPopulation          823
# CodeEventBootcamp        27
# CountryLive             825
# EmploymentField         476
# EmploymentStatus        792
# Gender                  833
# HasChildren             211
# HoursLearning           925
# Income                  430
# JobRoleInterest         402
# SchoolDegree            832
# SchoolMajor             622
# dtype: int64

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
attended_bc["BootcampName"].value_counts()
# Out:
# General Assembly                                                                 90
# Flatiron School                                                                  54
# Dev Bootcamp                                                                     48
# The Iron Yard                                                                    40
# Prime Digital Academy                                                            30
# Hack Reactor                                                                     29
# Turing                                                                           27
# App Academy                                                                      22
# Hackbright Academy                                                               22
# Code Fellows                                                                     21
# Bloc.io                                                                          21
# New York Code + Design Academy                                                   20
# Galvanize                                                                        20
# MakerSquare                                                                      20
# Coding Dojo                                                                      18
# The Firehose Project                                                             16
# Free Code Camp is not a bootcamp - please scroll up and change answer to "no"    15
# Epicodus                                                                         14
# Dev Academy                                                                      13
# Tech Talent South                                                                12
# Makers Academy                                                                   12
# Coder Camps                                                                      11
# DevMountain                                                                      10
# Viking Code School                                                               10
# Launch Academy                                                                   10
# Codeup                                                                           10
# Software Guild                                                                   10
# Ada                                                                               9
# 4Geeks Academy                                                                    8
# CodeaCamp                                                                         8
#                                                                                  ..
# codeU                                                                             1
# The Data Incubator                                                                1
# Science to Data Science                                                           1
# Launch School (formerly Tealeaf Academy)                                          1
# DESIGNATION                                                                       1
# Coder Foundry                                                                     1
# Code For Progress                                                                 1
# Code Institute                                                                    1
# Founders & Coders                                                                 1
# Operation Spark                                                                   1
# Microsoft Research Data Science Summer School                                     1
# Ruby On The Beach                                                                 1
# Alphappl                                                                          1
# Betamore                                                                          1
# Astro Code School                                                                 1
# Origin Code Academy                                                               1
# World Tech Makers                                                                 1
# CodeMasters Academy                                                               1
# Data Science Dojo                                                                 1
# Stackademy                                                                        1
# Austin Coding Academy                                                             1
# TalentBuddy                                                                       1
# Atlanta Code                                                                      1
# Base10 Academy                                                                    1
# Coder's Lab                                                                       1
# Interface Web School                                                              1
# Ladies Learning Code                                                              1
# Claim Academy                                                                     1
# SeedPaths                                                                         1
# CodeCraft School                                                                  1
# Name: BootcampName, Length: 128, dtype: int64

# %%
#filter schools with fewer than 10 attendents and save as df
schoolList = attended_bc.groupby("BootcampName").filter(lambda x :len(x) > 9)
#schoolList["BootcampName"].value_counts()
schoolList_df = pd.DataFrame(schoolList["BootcampName"].value_counts())
#schoolList_df.rese
schoolList_df.reset_index()
schoolList_df["Bootcamp Name"] = schoolList_df.index
schoolList_df
# Out:
#                                                     BootcampName  \
# General Assembly                                              90
# Flatiron School                                               54
# Dev Bootcamp                                                  48
# The Iron Yard                                                 40
# Prime Digital Academy                                         30
# Hack Reactor                                                  29
# Turing                                                        27
# Hackbright Academy                                            22
# App Academy                                                   22
# Code Fellows                                                  21
# Bloc.io                                                       21
# Galvanize                                                     20
# MakerSquare                                                   20
# New York Code + Design Academy                                20
# Coding Dojo                                                   18
# The Firehose Project                                          16
# Free Code Camp is not a bootcamp - please scrol...            15
# Epicodus                                                      14
# Dev Academy                                                   13
# Makers Academy                                                12
# Tech Talent South                                             12
# Coder Camps                                                   11
# Launch Academy                                                10
# DevMountain                                                   10
# Viking Code School                                            10
# Codeup                                                        10
# Software Guild                                                10
#
#                                                                                         Bootcamp Name
# General Assembly                                                                     General Assembly
# Flatiron School                                                                       Flatiron School
# Dev Bootcamp                                                                             Dev Bootcamp
# The Iron Yard                                                                           The Iron Yard
# Prime Digital Academy                                                           Prime Digital Academy
# Hack Reactor                                                                             Hack Reactor
# Turing                                                                                         Turing
# Hackbright Academy                                                                 Hackbright Academy
# App Academy                                                                               App Academy
# Code Fellows                                                                             Code Fellows
# Bloc.io                                                                                       Bloc.io
# Galvanize                                                                                   Galvanize
# MakerSquare                                                                               MakerSquare
# New York Code + Design Academy                                         New York Code + Design Academy
# Coding Dojo                                                                               Coding Dojo
# The Firehose Project                                                             The Firehose Project
# Free Code Camp is not a bootcamp - please scrol...  Free Code Camp is not a bootcamp - please scro...
# Epicodus                                                                                     Epicodus
# Dev Academy                                                                               Dev Academy
# Makers Academy                                                                         Makers Academy
# Tech Talent South                                                                   Tech Talent South
# Coder Camps                                                                               Coder Camps
# Launch Academy                                                                         Launch Academy
# DevMountain                                                                               DevMountain
# Viking Code School                                                                 Viking Code School
# Codeup                                                                                         Codeup
# Software Guild                                                                         Software Guild

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
schoolRec = schoolList.loc[schoolList["BootcampRecommend"] == "Yes"]
schoolRec_df = pd.DataFrame(schoolRec["BootcampName"].value_counts())
schoolRec_df.reset_index().rename(columns = {'index': 'name', "BootcampName": "n_Recommend"})
schoolRec_df["Bootcamp Name"] = schoolRec_df.index
schoolRec_df
# Out:
#                                                     BootcampName  \
# General Assembly                                              70
# Flatiron School                                               50
# Dev Bootcamp                                                  41
# The Iron Yard                                                 31
# Hack Reactor                                                  27
# Turing                                                        26
# Prime Digital Academy                                         25
# App Academy                                                   20
# Hackbright Academy                                            19
# MakerSquare                                                   18
# Code Fellows                                                  15
# New York Code + Design Academy                                14
# Free Code Camp is not a bootcamp - please scrol...            14
# The Firehose Project                                          13
# Dev Academy                                                   13
# Makers Academy                                                12
# Galvanize                                                     11
# Coding Dojo                                                   11
# Bloc.io                                                       11
# Epicodus                                                      11
# Viking Code School                                            10
# Launch Academy                                                 8
# Software Guild                                                 8
# Tech Talent South                                              8
# DevMountain                                                    8
# Codeup                                                         6
# Coder Camps                                                    6
#
#                                                                                         Bootcamp Name
# General Assembly                                                                     General Assembly
# Flatiron School                                                                       Flatiron School
# Dev Bootcamp                                                                             Dev Bootcamp
# The Iron Yard                                                                           The Iron Yard
# Hack Reactor                                                                             Hack Reactor
# Turing                                                                                         Turing
# Prime Digital Academy                                                           Prime Digital Academy
# App Academy                                                                               App Academy
# Hackbright Academy                                                                 Hackbright Academy
# MakerSquare                                                                               MakerSquare
# Code Fellows                                                                             Code Fellows
# New York Code + Design Academy                                         New York Code + Design Academy
# Free Code Camp is not a bootcamp - please scrol...  Free Code Camp is not a bootcamp - please scro...
# The Firehose Project                                                             The Firehose Project
# Dev Academy                                                                               Dev Academy
# Makers Academy                                                                         Makers Academy
# Galvanize                                                                                   Galvanize
# Coding Dojo                                                                               Coding Dojo
# Bloc.io                                                                                       Bloc.io
# Epicodus                                                                                     Epicodus
# Viking Code School                                                                 Viking Code School
# Launch Academy                                                                         Launch Academy
# Software Guild                                                                         Software Guild
# Tech Talent South                                                                   Tech Talent South
# DevMountain                                                                               DevMountain
# Codeup                                                                                         Codeup
# Coder Camps                                                                               Coder Camps

# %%
# Merge the two created data frames on the name of tbe bootcamp
combined_df = pd.merge(schoolList_df, schoolRec_df, how = 'left', on = "Bootcamp Name" )
combined_df
# Out:
#     BootcampName_x                                      Bootcamp Name  \
# 0               90                                   General Assembly
# 1               54                                    Flatiron School
# 2               48                                       Dev Bootcamp
# 3               40                                      The Iron Yard
# 4               30                              Prime Digital Academy
# 5               29                                       Hack Reactor
# 6               27                                             Turing
# 7               22                                 Hackbright Academy
# 8               22                                        App Academy
# 9               21                                       Code Fellows
# 10              21                                            Bloc.io
# 11              20                                          Galvanize
# 12              20                                        MakerSquare
# 13              20                     New York Code + Design Academy
# 14              18                                        Coding Dojo
# 15              16                               The Firehose Project
# 16              15  Free Code Camp is not a bootcamp - please scro...
# 17              14                                           Epicodus
# 18              13                                        Dev Academy
# 19              12                                     Makers Academy
# 20              12                                  Tech Talent South
# 21              11                                        Coder Camps
# 22              10                                     Launch Academy
# 23              10                                        DevMountain
# 24              10                                 Viking Code School
# 25              10                                             Codeup
# 26              10                                     Software Guild
#
#     BootcampName_y
# 0               70
# 1               50
# 2               41
# 3               31
# 4               25
# 5               27
# 6               26
# 7               19
# 8               20
# 9               15
# 10              11
# 11              11
# 12              18
# 13              14
# 14              11
# 15              13
# 16              14
# 17              11
# 18              13
# 19              12
# 20               8
# 21               6
# 22               8
# 23               8
# 24              10
# 25               6
# 26               8

# %%
# Calculate percentage of each bootcamp's students who are recommenders
combined_df["% Recommend"] = combined_df["BootcampName_y"]/combined_df["BootcampName_x"]*100
final_df = combined_df[["Bootcamp Name", "% Recommend"]].reset_index(drop = True)
final_df = final_df.sort_values("% Recommend", ascending = False).round(2)

final_df['% Recommend'] = final_df['% Recommend'].map("{}%".format)
final_df
# Out:
#                                         Bootcamp Name % Recommend
# 19                                     Makers Academy      100.0%
# 18                                        Dev Academy      100.0%
# 24                                 Viking Code School      100.0%
# 6                                              Turing       96.3%
# 16  Free Code Camp is not a bootcamp - please scro...      93.33%
# 5                                        Hack Reactor       93.1%
# 1                                     Flatiron School      92.59%
# 8                                         App Academy      90.91%
# 12                                        MakerSquare       90.0%
# 7                                  Hackbright Academy      86.36%
# 2                                        Dev Bootcamp      85.42%
# 4                               Prime Digital Academy      83.33%
# 15                               The Firehose Project      81.25%
# 23                                        DevMountain       80.0%
# 22                                     Launch Academy       80.0%
# 26                                     Software Guild       80.0%
# 17                                           Epicodus      78.57%
# 0                                    General Assembly      77.78%
# 3                                       The Iron Yard       77.5%
# 9                                        Code Fellows      71.43%
# 13                     New York Code + Design Academy       70.0%
# 20                                  Tech Talent South      66.67%
# 14                                        Coding Dojo      61.11%
# 25                                             Codeup       60.0%
# 11                                          Galvanize       55.0%
# 21                                        Coder Camps      54.55%
# 10                                            Bloc.io      52.38%

# %%
# Export to excel and remove index
writer = pd.ExcelWriter("bootcamps.xlsx", engine='xlsxwriter')
final_df.to_excel(writer,sheet_name = "dataframe", index=False)
writer.save()
